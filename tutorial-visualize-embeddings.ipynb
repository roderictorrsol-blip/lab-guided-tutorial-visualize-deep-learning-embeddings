# %% [markdown]
# # Visualizing word embeddings : Deep Learning for NLP embeddings.
#
# This notebook will guide you through the implementation of Word2Vec, a popular model used in Natural Language Processing (NLP) to capture semantic meaning from text. We will apply this model to a dataset and visualize the learned word embeddings.

# %% [markdown]
# <center><img src="https://education-team-2020.s3.eu-west-1.amazonaws.com/ai-eng/w4-s3/deep_learning.png" width="1000"/></center>

# %% [markdown]
# ## Tutorial
#
# In this notebook, we will apply the Word2Vec model to a text dataset. The Word2Vec model learns to represent words in a continuous vector space, where semantically similar words are mapped to nearby points. We will walk through the following steps:
#
# 1. **Download the Training Data:** We'll start by downloading a large text corpus for training.
# 2. **Set up Word2Vec in TensorFlow:** We'll configure the Word2Vec model using TensorFlow, a popular machine learning library.
# 3. **Train the Model:** We'll train the Word2Vec model on the dataset to learn word embeddings.
# 4. **Visualize the Embeddings:** Finally, we'll visualize the learned word embeddings using dimensionality reduction techniques.

# %%
reset -fs

# %%
# I like to live dangerously ☠
import warnings
warnings.filterwarnings('ignore')

# %%
# %pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (2.20.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow) (25.0)
# Requirement already satisfied: protobuf>=5.28.0 in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow) (6.33.5)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow) (2.32.5)
# Requirement already satisfied: setuptools in c:\program files\windowsapps\pythonsoftwarefoundation.python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\lib\site-packages (from tensorflow) (65.5.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow) (2.1.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow) (1.78.0)
# Requirement already satisfied: tensorboard~=2.20.0 in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow) (3.13.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow) (2.3.5)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow) (3.15.1)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from astunparse>=1.6.0->tensorflow) (0.46.3)
# Requirement already satisfied: rich in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from keras>=3.10.0->tensorflow) (14.3.2)
# Requirement already satisfied: namex in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from keras>=3.10.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from keras>=3.10.0->tensorflow) (0.18.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3,>=2.21.0->tensorflow) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3,>=2.21.0->tensorflow) (2.6.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3,>=2.21.0->tensorflow) (2025.11.12)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorboard~=2.20.0->tensorflow) (3.10.1)
# Requirement already satisfied: pillow in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorboard~=2.20.0->tensorflow) (12.0.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorboard~=2.20.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorboard~=2.20.0->tensorflow) (3.1.5)
# Requirement already satisfied: markupsafe>=2.1.1 in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from rich->keras>=3.10.0->tensorflow) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from rich->keras>=3.10.0->tensorflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 26.0
# [notice] To update, run: C:\Users\Usuario\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import collections
import math
import os
from pprint import pprint
import random
import urllib.request
import zipfile

import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf 
from sklearn.manifold import TSNE

# %matplotlib inline

# %% [markdown]
# ### Step 1: Download the Dataset
#
# To train our Word2Vec model, we need a large text corpus. In this step, we will download the "text8" dataset, a popular dataset used for training word embeddings. This dataset contains 100 MB of English Wikipedia text from 2006, which is commonly used in NLP tasks.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(path, filename, expected_bytes):
    """Download a file if not present, and make sure it's the right size."""
    
    if not os.path.exists(path+filename):
        filename, _ = urllib.request.urlretrieve(url + filename, filename)
    
    statinfo = os.stat(path+filename)
    if statinfo.st_size == expected_bytes:
        print('Found and verified', filename)
    else:
        print(statinfo.st_size)
        raise Exception(
            'Failed to verify ' + filename + '. Can you get to it with a browser?')
    
    return filename

path = ""
filename = maybe_download(path, 'text8.zip', 31_344_016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# > **Note:** While the dataset is being downloaded, feel free to look ahead at the upcoming code cells to get a sense of what we'll be doing next.

# %%
# Read the data into a list of strings.
def read_data(path, filename):
    """Extract the first file enclosed in a zip file as a list of words"""
    with zipfile.ZipFile(path+filename) as f:
        data = tf.compat.as_str(f.read(f.namelist()[0])).split()
    return data

vocabulary = read_data(path, filename)
print('Dataset size: {:,} words'.format(len(vocabulary)))
# Out:
# Dataset size: 17,005,207 words

# %%
# Take a peak at the head
vocabulary[:20]
# Out:
# ['anarchism',
#  'originated',
#  'as',
#  'a',
#  'term',
#  'of',
#  'abuse',
#  'first',
#  'used',
#  'against',
#  'early',
#  'working',
#  'class',
#  'radicals',
#  'including',
#  'the',
#  'diggers',
#  'of',
#  'the',
#  'english']

# %% [markdown]
# ### Observations on Preprocessing
#
# - **Case and Punctuation:** Notice that none of the words in our dataset are capitalized, and there is no punctuation. This is likely due to preprocessing steps taken before we acquired the dataset, which ensures uniformity in the text.
# - **Preprocessing Considerations:** Preprocessing is a crucial part of NLP tasks, and its specifics depend on the data and the intended use. For instance, while we're working with unigrams (single words), other tasks might benefit from encoding n-grams (combinations of words) to capture context better.

# %% [markdown]
# -----
# Step 2: Build the dictionary
# -----

# %% [markdown]
# Now that we have our text data, the next step is to build a dictionary. This dictionary will map each unique word in our dataset to a unique integer code.
#
# Additionally, we'll keep track of the frequency of each word, which will help us prioritize the most common words.

# %%
vocabulary_size = 50_000

def build_dataset(words, n_words):
    """Process raw inputs into a dataset."""
    count = [['UNK', -1]]
    count.extend(collections.Counter(words).most_common(n_words - 1))
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)
    data = list()
    unk_count = 0
    for word in words:
        index = dictionary.get(word, 0)
        if index == 0:  # dictionary['UNK']
            unk_count += 1
        data.append(index)
    count[0][1] = unk_count
    reversed_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
    return data, count, dictionary, reversed_dictionary

# %%
data, count, dictionary, reverse_dictionary = build_dataset(vocabulary,
                                                            vocabulary_size)

# %% [markdown]
# ### Understanding the Key Variables
#
# - **`data`:** A list of integer codes representing the words in the original text. Each word is replaced by its corresponding code from the `dictionary`.
# - **`count`:** A list of tuples where each tuple contains a word and its frequency count in the dataset.
# - **`dictionary`:** A dictionary mapping each word to its unique integer code.
# - **`reverse_dictionary`:** A reverse mapping that converts integer codes back to their corresponding words.

# %%
del vocabulary # Reduce memory by getting rid of the "heavy" list of strings

# %%
data[:5] # An index of each word (as it appears in order) to its rank. Therefore we don't have reference the string
# Out:
# [5234, 3081, 12, 6, 195]

# %%
dictionary['the'] # word: rank
# Out:
# 1

# %%
reverse_dictionary[5234] # rank: word
# Out:
# 'anarchism'

# %%
print('Most common words:') 
print(*count[:5], sep="\n")
# Out:
# Most common words:
# ['UNK', 418391]
# ('the', 1061396)
# ('of', 593677)
# ('and', 416629)
# ('one', 411764)

# %%
print('Least common words:')
print(*count[-5:], sep="\n")
# Out:
# Least common words:
# ('codeword', 9)
# ('senussi', 9)
# ('unscr', 9)
# ('leonards', 9)
# ('hif', 9)

# %% [markdown]
# ### Step 3: Generate a Training Batch for the Skip-Gram Model
#
# In this step, we'll create a function to generate training batches for our skip-gram model. The skip-gram model is a variant of Word2Vec that predicts the context words given a target word. This function will help us prepare the data in the correct format for training the model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1  # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)
    if data_index + span > len(data):
        data_index = 0
    buffer.extend(data[data_index:data_index + span])
    data_index += span
    for i in range(batch_size // num_skips):
        context_words = [w for w in range(span) if w != skip_window]
        words_to_use = random.sample(context_words, num_skips)
        for j, context_word in enumerate(words_to_use):
            batch[i * num_skips + j] = buffer[skip_window]
            labels[i * num_skips + j, 0] = buffer[context_word]
        if data_index == len(data):
            buffer[:] = data[:span]
            data_index = span
        else:
            buffer.append(data[data_index])
            data_index += 1
    # Backtrack a little bit to avoid skipping words in the end of a batch
    data_index = (data_index + len(data) - span) % len(data)
    return batch, labels

# %%
batch, labels = generate_batch(batch_size=8, 
                               num_skips=2, 
                               skip_window=1)

# %%
# Example of self-supervised learning
for i in range(8):
    print(batch[i], reverse_dictionary[batch[i]],
        '->', labels[i, 0], reverse_dictionary[labels[i, 0]])
# Out:
# 3081 originated -> 12 as
# 3081 originated -> 5234 anarchism
# 12 as -> 3081 originated
# 12 as -> 6 a
# 6 a -> 12 as
# 6 a -> 195 term
# 195 term -> 2 of
# 195 term -> 6 a

# %% [markdown]
# ----
# Step 4: Build and train a skip-gram model.
# -----
#
# The Skip-Gram model is a type of neural network model used in Natural Language Processing (NLP) to learn distributed representations of words, commonly known as word embeddings.
#
# Word embeddings are dense vector representations of words that capture semantic relationships between them, meaning that words with similar meanings are mapped to similar points in the vector space.
#
# ### How the Skip-Gram Model Works
# The goal of the Skip-Gram model is to predict the context words given a target word. Here's how it works:
#
# Input: The model takes a single word (the target word) from the text as input.
#
# Output: The model is trained to predict words that are likely to appear in the context of the target word within a specified window of words before and after the target word. This context window is typically referred to as the "skip window."
#
# For example, if the sentence is "The cat sat on the mat," and the target word is "sat," the model might be asked to predict the words "The," "cat," "on," and "the," which appear around "sat."

# %%
batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
skip_window = 1       # How many words to consider left and right.
num_skips = 2         # How many times to reuse an input to generate a label.
num_sampled = 64      # Number of negative examples to sample.

# We pick a random validation set to sample nearest neighbors. Here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent.
valid_size = 16     # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution.
valid_examples = np.random.choice(valid_window, valid_size, replace=False)

# %%
import tensorflow.compat.v1 as v1

# %%
graph = tf.Graph()

with graph.as_default():

    # Input data.
    train_inputs = v1.placeholder(tf.int32, shape=[batch_size])
    train_labels = v1.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = v1.constant(valid_examples, dtype=tf.int32)

    with tf.device('/cpu:0'):
        # Look up embeddings for inputs.
        embeddings = tf.Variable(
            v1.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
        embed = tf.nn.embedding_lookup(embeddings, train_inputs)

        # Construct the variables for the NCE loss
        nce_weights = tf.Variable(
            v1.truncated_normal([vocabulary_size, embedding_size],
                                stddev=1.0 / math.sqrt(embedding_size)))
        nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

        # Compute the average NCE loss for the batch.
        # tf.nce_loss automatically draws a new sample of the negative labels each
        # time we evaluate the loss.
        # Explanation of the meaning of NCE loss:
        #   http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/
        loss = tf.reduce_mean(
          tf.nn.nce_loss(weights=nce_weights,
                         biases=nce_biases,
                         labels=train_labels,
                         inputs=embed,
                         num_sampled=num_sampled,
                         num_classes=vocabulary_size))

        # Construct the SGD optimizer using a learning rate of 1.0.
        optimizer = v1.train.GradientDescentOptimizer(1.0).minimize(loss)

        # Compute the cosine similarity between minibatch examples and all embeddings.
        norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keepdims=True))
        normalized_embeddings = embeddings / norm
        valid_embeddings = tf.nn.embedding_lookup(
          normalized_embeddings, valid_dataset)
        similarity = tf.matmul(
          valid_embeddings, normalized_embeddings, transpose_b=True)

        # Add variable initializer.
        init = v1.global_variables_initializer()
# Out:
# WARNING:tensorflow:From C:\Users\Usuario\AppData\Local\Temp\ipykernel_5068\701590837.py:6: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From C:\Users\Usuario\AppData\Local\Temp\ipykernel_5068\701590837.py:36: The name tf.train.GradientDescentOptimizer is deprecated. Please use tf.compat.v1.train.GradientDescentOptimizer instead.

# %% [markdown]
# ----
# Step 5: Begin training.
# -----

# %%
num_steps = 100_001 #1 #2_001 #100_001

with v1.Session(graph=graph) as session:
    # We must initialize all variables before we use them.
    init.run()
    print("Initialized")

    average_loss = 0
    for step in range(num_steps):
        batch_inputs, batch_labels = generate_batch(
            batch_size, num_skips, skip_window)
        feed_dict = {train_inputs : batch_inputs, train_labels : batch_labels}

        # We perform one update step by evaluating the optimizer op (including it
        # in the list of returned values for session.run()
        _, loss_val = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += loss_val

        if step % 2_000 == 0:
            if step > 0:
                average_loss /= 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print("Average loss at step ", step, ": ", average_loss)
            average_loss = 0

        # Note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 2_000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 4 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log_str = "Nearest to '%s':" % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log_str = "%s %s," % (log_str, close_word)
                print(log_str)
            print()
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step  0 :  278.9364
# Nearest to 'from': carcinogenic, studs, deccan, wakko,
# Nearest to 'with': romana, autonomously, gemini, sega,
# Nearest to 'five': dee, pcs, gutman, seam,
# Nearest to 'an': fullerenes, ayyubid, goldstein, ipcc,
# Nearest to 'would': delegates, footing, folktales, concentrations,
# Nearest to 'some': interferes, inwards, transponder, jockeys,
# Nearest to 'eight': hanoi, doubted, darby, piron,
# Nearest to 'world': integrase, telecasts, novel, nationally,
# Nearest to 'a': featured, sommerfeld, lately, blige,
# Nearest to 'it': enid, flared, motive, glans,
# Nearest to 'about': sc, heal, ecclesia, jah,
# Nearest to 'as': nh, vehemently, reverse, dragoons,
# Nearest to 'his': alsatian, hell, summits, falconer,
# Nearest to 'united': warren, lessens, dmt, homoerotic,
# Nearest to 'states': lending, biplanes, paula, noa,
# Nearest to 'history': serie, geocentric, foundered, abjuration,
#
# Average loss at step  2000 :  113.55346
# Nearest to 'from': zero, brooke, transcontinental, basic,
# Nearest to 'with': coast, support, ideas, queensland,
# Nearest to 'five': taggart, capitalism, finalist, cause,
# Nearest to 'an': indeed, one, person, berber,
# Nearest to 'would': can, all, slavery, style,
# Nearest to 'some': transponder, or, jpg, finalist,
# Nearest to 'eight': state, development, chadic, collectivism,
# Nearest to 'world': novel, anarchism, jpg, seconds,
# Nearest to 'a': the, ability, itself, sky,
# Nearest to 'it': rational, sky, commercial, writings,
# Nearest to 'about': child, british, heal, southern,
# Nearest to 'as': produced, into, limitations, autistic,
# Nearest to 'his': age, vs, according, zero,
# Nearest to 'united': anselm, him, moved, influences,
# Nearest to 'states': completely, produced, living, society,
# Nearest to 'history': receiving, objectivism, jpg, growth,
#
# Average loss at step  4000 :  52.960728
# Nearest to 'from': agave, transcontinental, brooke, cells,
# Nearest to 'with': in, of, and, tell,
# Nearest to 'five': zero, agave, conjugate, finalist,
# Nearest to 'an': indeed, one, anthem, identification,
# Nearest to 'would': delegates, can, as, all,
# Nearest to 'some': transponder, gdp, humans, tiny,
# Nearest to 'eight': agave, nine, fao, gland,
# Nearest to 'world': novel, seconds, jim, day,
# Nearest to 'a': the, itself, reginae, support,
# Nearest to 'it': reginae, fao, commercial, sky,
# Nearest to 'about': child, experiment, gland, heal,
# Nearest to 'as': into, produced, prosecution, date,
# Nearest to 'his': reginae, age, vs, according,
# Nearest to 'united': agave, entire, refrigerator, moved,
# Nearest to 'states': completely, produced, performing, living,
# Nearest to 'history': receiving, objectivism, disputes, growth,
#
# Average loss at step  6000 :  33.083702
# Nearest to 'from': in, agave, of, and,
# Nearest to 'with': in, of, and, tell,
# Nearest to 'five': zero, agave, hole, conjugate,
# Nearest to 'an': indeed, anthem, arabic, satellite,
# Nearest to 'would': can, delegates, as, style,
# Nearest to 'some': transponder, gdp, ep, tiny,
# Nearest to 'eight': agave, nine, fao, continuous,
# Nearest to 'world': novel, penalties, halo, aesthetically,
# Nearest to 'a': the, dred, and, support,
# Nearest to 'it': he, reginae, kosovo, fao,
# Nearest to 'about': child, experiment, and, heal,
# Nearest to 'as': into, prosecution, absorbed, produced,
# Nearest to 'his': rudolph, reginae, age, the,
# Nearest to 'united': agave, patriots, entire, refrigerator,
# Nearest to 'states': completely, produced, performing, mars,
# Nearest to 'history': receiving, bounded, iterative, objectivism,
#
# Average loss at step  8000 :  23.465542
# Nearest to 'from': in, of, agave, and,
# Nearest to 'with': in, and, of, phi,
# Nearest to 'five': zero, nine, UNK, phi,
# Nearest to 'an': completeness, indeed, anthem, arabic,
# Nearest to 'would': can, annexation, delegates, as,
# Nearest to 'some': billboard, UNK, transponder, gdp,
# Nearest to 'eight': nine, agave, zero, UNK,
# Nearest to 'world': novel, UNK, penalties, aesthetically,
# Nearest to 'a': the, UNK, dred, and,
# Nearest to 'it': he, UNK, ticonderoga, reginae,
# Nearest to 'about': sc, child, experiment, sagan,
# Nearest to 'as': UNK, and, into, in,
# Nearest to 'his': the, rudolph, reginae, age,
# Nearest to 'united': agave, patriots, electorate, entire,
# Nearest to 'states': archie, completely, produced, performing,
# Nearest to 'history': receiving, amu, iterative, bounded,
#
# Average loss at step  10000 :  17.853106
# Nearest to 'from': in, and, of, agave,
# Nearest to 'with': in, and, of, taste,
# Nearest to 'five': zero, nine, phi, one,
# Nearest to 'an': the, one, completeness, indeed,
# Nearest to 'would': can, delegates, annexation, as,
# Nearest to 'some': billboard, the, gdp, transponder,
# Nearest to 'eight': agave, nine, zero, archie,
# Nearest to 'world': novel, penalties, solf, seconds,
# Nearest to 'a': the, and, dred, UNK,
# Nearest to 'it': he, UNK, frau, ticonderoga,
# Nearest to 'about': sc, child, solf, experiment,
# Nearest to 'as': in, into, and, phi,
# Nearest to 'his': the, molinari, rudolph, age,
# Nearest to 'united': agave, patriots, electorate, entire,
# Nearest to 'states': completely, archie, lending, produced,
# Nearest to 'history': receiving, bounded, amu, iterative,
#
# Average loss at step  12000 :  14.076311
# Nearest to 'from': in, and, of, agave,
# Nearest to 'with': in, and, from, to,
# Nearest to 'five': nine, zero, phi, one,
# Nearest to 'an': one, completeness, indeed, subkey,
# Nearest to 'would': can, delegates, peptide, annexation,
# Nearest to 'some': the, billboard, edges, transponder,
# Nearest to 'eight': nine, agave, zero, archie,
# Nearest to 'world': penalties, solf, novel, jim,
# Nearest to 'a': the, dred, one, mctaggart,
# Nearest to 'it': he, gollancz, and, frau,
# Nearest to 'about': sc, child, solf, experiment,
# Nearest to 'as': in, and, into, phi,
# Nearest to 'his': the, molinari, rudolph, shortcuts,
# Nearest to 'united': agave, patriots, electorate, jubilees,
# Nearest to 'states': hydrophilic, completely, noa, archie,
# Nearest to 'history': receiving, iterative, bounded, amu,
#
# Average loss at step  14000 :  11.773264
# Nearest to 'from': in, and, of, agouti,
# Nearest to 'with': in, and, to, from,
# Nearest to 'five': agouti, zero, nine, dasyprocta,
# Nearest to 'an': the, dasyprocta, completeness, demand,
# Nearest to 'would': can, peptide, delegates, annexation,
# Nearest to 'some': the, dasyprocta, gollancz, inwards,
# Nearest to 'eight': nine, circ, zero, agave,
# Nearest to 'world': girardeau, solf, penalties, llama,
# Nearest to 'a': the, dred, operatorname, one,
# Nearest to 'it': he, dasyprocta, agouti, and,
# Nearest to 'about': agouti, sc, dasyprocta, child,
# Nearest to 'as': and, in, into, by,
# Nearest to 'his': the, molinari, rudolph, shortcuts,
# Nearest to 'united': agouti, agave, patriots, electorate,
# Nearest to 'states': hydrophilic, bolt, noa, completely,
# Nearest to 'history': circ, iterative, receiving, dasyprocta,
#
# Average loss at step  16000 :  9.84112
# Nearest to 'from': in, of, and, agouti,
# Nearest to 'with': in, and, of, from,
# Nearest to 'five': zero, nine, agouti, one,
# Nearest to 'an': dasyprocta, its, completeness, the,
# Nearest to 'would': can, peptide, delegates, annexation,
# Nearest to 'some': the, dasyprocta, this, inwards,
# Nearest to 'eight': nine, zero, seven, two,
# Nearest to 'world': girardeau, solf, penalties, llama,
# Nearest to 'a': the, operatorname, dred, their,
# Nearest to 'it': he, dasyprocta, agouti, cooper,
# Nearest to 'about': agouti, sc, nine, child,
# Nearest to 'as': in, and, into, by,
# Nearest to 'his': the, molinari, their, rudolph,
# Nearest to 'united': agouti, dmt, electorate, agave,
# Nearest to 'states': hydrophilic, bolt, noa, lending,
# Nearest to 'history': iterative, circ, receiving, dasyprocta,
#
# Average loss at step  18000 :  8.381436
# Nearest to 'from': in, and, agouti, of,
# Nearest to 'with': in, and, from, of,
# Nearest to 'five': nine, agouti, zero, two,
# Nearest to 'an': the, its, dasyprocta, completeness,
# Nearest to 'would': can, peptide, delegates, annexation,
# Nearest to 'some': the, this, dasyprocta, inwards,
# Nearest to 'eight': nine, zero, agouti, seven,
# Nearest to 'world': two, solf, girardeau, penalties,
# Nearest to 'a': the, operatorname, their, circ,
# Nearest to 'it': he, dasyprocta, agouti, easter,
# Nearest to 'about': agouti, sc, dasyprocta, child,
# Nearest to 'as': by, into, is, and,
# Nearest to 'his': the, their, molinari, s,
# Nearest to 'united': agouti, dmt, electorate, agave,
# Nearest to 'states': hydrophilic, bolt, noa, lending,
# Nearest to 'history': circ, iterative, dasyprocta, bounded,
#
# Average loss at step  20000 :  8.136949
# Nearest to 'from': and, in, agouti, of,
# Nearest to 'with': in, and, of, as,
# Nearest to 'five': nine, zero, eight, four,
# Nearest to 'an': the, its, completeness, dasyprocta,
# Nearest to 'would': can, peptide, delegates, annexation,
# Nearest to 'some': the, this, dasyprocta, inwards,
# Nearest to 'eight': nine, zero, seven, six,
# Nearest to 'world': girardeau, solf, penalties, llama,
# Nearest to 'a': the, operatorname, their, circ,
# Nearest to 'it': he, dasyprocta, agouti, UNK,
# Nearest to 'about': sc, agouti, ecclesia, dasyprocta,
# Nearest to 'as': and, by, is, was,
# Nearest to 'his': the, their, s, rudolph,
# Nearest to 'united': agouti, electorate, dmt, agave,
# Nearest to 'states': hydrophilic, bolt, noa, archie,
# Nearest to 'history': circ, iterative, dasyprocta, bounded,
#
# Average loss at step  22000 :  6.980858
# Nearest to 'from': and, in, agouti, of,
# Nearest to 'with': in, and, from, as,
# Nearest to 'five': nine, zero, two, eight,
# Nearest to 'an': the, its, completeness, dasyprocta,
# Nearest to 'would': can, peptide, delegates, resizing,
# Nearest to 'some': the, this, dasyprocta, gollancz,
# Nearest to 'eight': nine, zero, six, seven,
# Nearest to 'world': girardeau, solf, penalties, llama,
# Nearest to 'a': the, operatorname, circ, their,
# Nearest to 'it': he, dasyprocta, there, this,
# Nearest to 'about': sc, agouti, ecclesia, one,
# Nearest to 'as': by, in, and, is,
# Nearest to 'his': the, their, rudolph, its,
# Nearest to 'united': electorate, patriots, dmt, agouti,
# Nearest to 'states': hydrophilic, bolt, noa, archie,
# Nearest to 'history': circ, dasyprocta, iterative, bounded,
#
# Average loss at step  24000 :  6.9013824
# Nearest to 'from': and, agouti, in, for,
# Nearest to 'with': in, and, as, from,
# Nearest to 'five': nine, zero, six, eight,
# Nearest to 'an': its, completeness, the, dasyprocta,
# Nearest to 'would': can, peptide, delegates, resizing,
# Nearest to 'some': the, this, dasyprocta, gollancz,
# Nearest to 'eight': nine, six, zero, seven,
# Nearest to 'world': girardeau, solf, penalties, llama,
# Nearest to 'a': the, their, operatorname, or,
# Nearest to 'it': he, this, there, dasyprocta,
# Nearest to 'about': sc, agouti, ecclesia, dasyprocta,
# Nearest to 'as': by, is, was, into,
# Nearest to 'his': the, their, rudolph, its,
# Nearest to 'united': patriots, electorate, agouti, dmt,
# Nearest to 'states': hydrophilic, bolt, noa, archie,
# Nearest to 'history': iterative, circ, dasyprocta, bounded,
#
# Average loss at step  26000 :  6.7525907
# Nearest to 'from': and, in, agouti, of,
# Nearest to 'with': in, and, from, as,
# Nearest to 'five': four, six, nine, eight,
# Nearest to 'an': its, completeness, dasyprocta, indeed,
# Nearest to 'would': can, delegates, should, peptide,
# Nearest to 'some': this, the, goku, dasyprocta,
# Nearest to 'eight': nine, six, seven, four,
# Nearest to 'world': girardeau, penalties, solf, llama,
# Nearest to 'a': the, operatorname, or, circ,
# Nearest to 'it': he, this, there, dasyprocta,
# Nearest to 'about': sc, agouti, ecclesia, dasyprocta,
# Nearest to 'as': by, was, in, is,
# Nearest to 'his': the, their, her, its,
# Nearest to 'united': agouti, patriots, electorate, dmt,
# Nearest to 'states': hydrophilic, bolt, noa, lending,
# Nearest to 'history': serie, iterative, circ, bounded,
#
# Average loss at step  28000 :  6.4896464
# Nearest to 'from': in, agouti, and, for,
# Nearest to 'with': in, and, as, for,
# Nearest to 'five': eight, four, six, nine,
# Nearest to 'an': its, completeness, the, demand,
# Nearest to 'would': can, should, peptide, resizing,
# Nearest to 'some': the, this, adenylate, goku,
# Nearest to 'eight': nine, six, four, seven,
# Nearest to 'world': girardeau, solf, penalties, llama,
# Nearest to 'a': the, operatorname, or, archimedean,
# Nearest to 'it': he, this, there, agouti,
# Nearest to 'about': sc, agouti, ecclesia, dasyprocta,
# Nearest to 'as': by, was, with, in,
# Nearest to 'his': the, their, its, her,
# Nearest to 'united': agouti, patriots, electorate, dmt,
# Nearest to 'states': hydrophilic, bolt, noa, tremendously,
# Nearest to 'history': serie, circ, iterative, dasyprocta,
#
# Average loss at step  30000 :  5.9587197
# Nearest to 'from': in, and, agouti, for,
# Nearest to 'with': in, and, for, by,
# Nearest to 'five': four, six, eight, zero,
# Nearest to 'an': the, completeness, its, pliny,
# Nearest to 'would': can, should, resizing, peptide,
# Nearest to 'some': this, the, adenylate, goku,
# Nearest to 'eight': nine, six, seven, four,
# Nearest to 'world': girardeau, solf, penalties, llama,
# Nearest to 'a': the, operatorname, this, their,
# Nearest to 'it': he, this, there, aedh,
# Nearest to 'about': sc, agouti, ecclesia, six,
# Nearest to 'as': by, in, and, was,
# Nearest to 'his': the, their, her, its,
# Nearest to 'united': patriots, agouti, electorate, dmt,
# Nearest to 'states': hydrophilic, bolt, noa, tremendously,
# Nearest to 'history': serie, iterative, circ, dasyprocta,
#
# Average loss at step  32000 :  5.936081
# Nearest to 'from': in, and, of, agouti,
# Nearest to 'with': in, and, as, for,
# Nearest to 'five': four, six, seven, eight,
# Nearest to 'an': completeness, its, the, pliny,
# Nearest to 'would': can, should, will, resizing,
# Nearest to 'some': this, many, the, adenylate,
# Nearest to 'eight': nine, six, seven, four,
# Nearest to 'world': girardeau, solf, penalties, llama,
# Nearest to 'a': the, or, this, operatorname,
# Nearest to 'it': he, this, there, aedh,
# Nearest to 'about': sc, agouti, ecclesia, dasyprocta,
# Nearest to 'as': by, and, with, is,
# Nearest to 'his': their, the, her, its,
# Nearest to 'united': agouti, electorate, patriots, agave,
# Nearest to 'states': hydrophilic, bolt, noa, tremendously,
# Nearest to 'history': serie, dasyprocta, circ, iterative,
#
# Average loss at step  34000 :  5.718366
# Nearest to 'from': in, and, agouti, of,
# Nearest to 'with': in, and, as, for,
# Nearest to 'five': four, six, seven, three,
# Nearest to 'an': its, the, completeness, pliny,
# Nearest to 'would': can, should, will, resizing,
# Nearest to 'some': the, this, many, adenylate,
# Nearest to 'eight': nine, six, seven, four,
# Nearest to 'world': girardeau, solf, penalties, llama,
# Nearest to 'a': the, this, operatorname, circ,
# Nearest to 'it': he, this, there, which,
# Nearest to 'about': sc, agouti, ecclesia, dasyprocta,
# Nearest to 'as': by, poulsen, with, and,
# Nearest to 'his': their, the, her, its,
# Nearest to 'united': agouti, electorate, patriots, agave,
# Nearest to 'states': hydrophilic, bolt, archie, pelvic,
# Nearest to 'history': serie, iterative, dasyprocta, circ,
#
# Average loss at step  36000 :  5.789165
# Nearest to 'from': in, agouti, and, for,
# Nearest to 'with': in, for, as, and,
# Nearest to 'five': four, six, seven, three,
# Nearest to 'an': its, completeness, pliny, the,
# Nearest to 'would': can, should, will, resizing,
# Nearest to 'some': many, this, the, these,
# Nearest to 'eight': nine, seven, six, four,
# Nearest to 'world': girardeau, solf, penalties, increments,
# Nearest to 'a': the, this, operatorname, archimedean,
# Nearest to 'it': he, this, there, aedh,
# Nearest to 'about': sc, agouti, ecclesia, experiment,
# Nearest to 'as': poulsen, by, with, and,
# Nearest to 'his': the, their, her, its,
# Nearest to 'united': electorate, patriots, agouti, dmt,
# Nearest to 'states': hydrophilic, bolt, tremendously, noa,
# Nearest to 'history': serie, iterative, dasyprocta, bounded,
#
# Average loss at step  38000 :  5.4924116
# Nearest to 'from': in, and, on, agouti,
# Nearest to 'with': in, and, for, on,
# Nearest to 'five': four, six, seven, three,
# Nearest to 'an': its, completeness, the, pliny,
# Nearest to 'would': can, should, will, resizing,
# Nearest to 'some': many, this, the, these,
# Nearest to 'eight': nine, seven, six, four,
# Nearest to 'world': girardeau, penalties, solf, increments,
# Nearest to 'a': the, operatorname, archimedean, circ,
# Nearest to 'it': he, this, there, aedh,
# Nearest to 'about': sc, agouti, three, dasyprocta,
# Nearest to 'as': poulsen, by, agouti, with,
# Nearest to 'his': their, the, her, its,
# Nearest to 'united': agouti, electorate, patriots, agave,
# Nearest to 'states': hydrophilic, bolt, noa, tremendously,
# Nearest to 'history': serie, iterative, dasyprocta, circ,
#
# Average loss at step  40000 :  5.273518
# Nearest to 'from': in, agouti, into, phi,
# Nearest to 'with': in, and, on, by,
# Nearest to 'five': four, six, seven, eight,
# Nearest to 'an': its, completeness, pliny, dasyprocta,
# Nearest to 'would': can, should, will, resizing,
# Nearest to 'some': many, the, this, any,
# Nearest to 'eight': seven, six, nine, four,
# Nearest to 'world': girardeau, penalties, solf, llama,
# Nearest to 'a': the, operatorname, circ, archimedean,
# Nearest to 'it': he, this, there, which,
# Nearest to 'about': sc, agouti, three, ecclesia,
# Nearest to 'as': poulsen, agouti, by, archie,
# Nearest to 'his': their, the, her, its,
# Nearest to 'united': agouti, electorate, patriots, agave,
# Nearest to 'states': hydrophilic, bolt, five, tremendously,
# Nearest to 'history': serie, dasyprocta, circ, iterative,
#
# Average loss at step  42000 :  5.401515
# Nearest to 'from': agouti, in, agave, phi,
# Nearest to 'with': in, and, from, by,
# Nearest to 'five': six, four, seven, three,
# Nearest to 'an': its, completeness, demand, pliny,
# Nearest to 'would': can, should, will, resizing,
# Nearest to 'some': many, the, any, this,
# Nearest to 'eight': seven, nine, six, four,
# Nearest to 'world': girardeau, penalties, llama, increments,
# Nearest to 'a': the, operatorname, archimedean, circ,
# Nearest to 'it': he, this, there, which,
# Nearest to 'about': sc, agouti, three, ecclesia,
# Nearest to 'as': poulsen, by, agouti, is,
# Nearest to 'his': their, the, its, her,
# Nearest to 'united': agouti, electorate, patriots, agave,
# Nearest to 'states': hydrophilic, bolt, tremendously, pelvic,
# Nearest to 'history': serie, dasyprocta, circ, iterative,
#
# Average loss at step  44000 :  5.277431
# Nearest to 'from': in, agouti, into, for,
# Nearest to 'with': in, and, dasyprocta, for,
# Nearest to 'five': six, four, three, seven,
# Nearest to 'an': its, completeness, demand, fullerenes,
# Nearest to 'would': can, should, will, resizing,
# Nearest to 'some': many, this, these, any,
# Nearest to 'eight': nine, seven, six, four,
# Nearest to 'world': girardeau, penalties, increments, llama,
# Nearest to 'a': the, this, operatorname, archimedean,
# Nearest to 'it': he, this, there, which,
# Nearest to 'about': sc, agouti, three, ecclesia,
# Nearest to 'as': poulsen, by, agouti, in,
# Nearest to 'his': their, the, its, her,
# Nearest to 'united': agouti, electorate, agave, patriots,
# Nearest to 'states': hydrophilic, bolt, tremendously, noa,
# Nearest to 'history': serie, dasyprocta, circ, iterative,
#
# Average loss at step  46000 :  5.187036
# Nearest to 'from': in, agouti, for, into,
# Nearest to 'with': in, and, for, from,
# Nearest to 'five': four, six, three, seven,
# Nearest to 'an': completeness, its, demand, pliny,
# Nearest to 'would': can, should, will, resizing,
# Nearest to 'some': many, these, any, this,
# Nearest to 'eight': nine, seven, six, four,
# Nearest to 'world': girardeau, penalties, solf, increments,
# Nearest to 'a': the, this, operatorname, archimedean,
# Nearest to 'it': he, this, there, which,
# Nearest to 'about': sc, agouti, three, experiment,
# Nearest to 'as': poulsen, by, agouti, in,
# Nearest to 'his': their, the, her, its,
# Nearest to 'united': electorate, agouti, of, patriots,
# Nearest to 'states': hydrophilic, bolt, tremendously, noa,
# Nearest to 'history': serie, circ, dasyprocta, trophies,
#
# Average loss at step  48000 :  5.2415566
# Nearest to 'from': in, into, agouti, and,
# Nearest to 'with': in, and, from, as,
# Nearest to 'five': six, four, three, seven,
# Nearest to 'an': completeness, demand, its, pliny,
# Nearest to 'would': can, should, will, could,
# Nearest to 'some': many, these, the, this,
# Nearest to 'eight': nine, seven, six, four,
# Nearest to 'world': girardeau, penalties, increments, llama,
# Nearest to 'a': the, this, archimedean, operatorname,
# Nearest to 'it': he, this, there, which,
# Nearest to 'about': sc, agouti, experiment, three,
# Nearest to 'as': poulsen, by, agouti, archie,
# Nearest to 'his': their, the, its, her,
# Nearest to 'united': electorate, agouti, patriots, dmt,
# Nearest to 'states': hydrophilic, bolt, tremendously, noa,
# Nearest to 'history': serie, circ, dasyprocta, trophies,
#
# Average loss at step  50000 :  5.004646
# Nearest to 'from': in, into, for, agouti,
# Nearest to 'with': in, and, or, for,
# Nearest to 'five': six, four, three, seven,
# Nearest to 'an': completeness, its, demand, pliny,
# Nearest to 'would': can, will, should, could,
# Nearest to 'some': many, these, any, this,
# Nearest to 'eight': seven, six, nine, four,
# Nearest to 'world': girardeau, penalties, four, increments,
# Nearest to 'a': the, this, operatorname, circ,
# Nearest to 'it': he, this, there, which,
# Nearest to 'about': sc, agouti, three, experiment,
# Nearest to 'as': by, poulsen, agouti, archie,
# Nearest to 'his': their, the, its, her,
# Nearest to 'united': electorate, agouti, patriots, agave,
# Nearest to 'states': hydrophilic, bolt, tremendously, noa,
# Nearest to 'history': serie, circ, dasyprocta, trophies,
#
# Average loss at step  52000 :  5.026306
# Nearest to 'from': in, into, agouti, on,
# Nearest to 'with': in, or, ursus, and,
# Nearest to 'five': six, four, three, seven,
# Nearest to 'an': completeness, its, demand, rgb,
# Nearest to 'would': can, will, should, could,
# Nearest to 'some': many, the, these, any,
# Nearest to 'eight': seven, nine, six, four,
# Nearest to 'world': girardeau, penalties, increments, llama,
# Nearest to 'a': the, ursus, operatorname, no,
# Nearest to 'it': he, this, there, which,
# Nearest to 'about': sc, agouti, ursus, three,
# Nearest to 'as': ursus, biathlon, poulsen, by,
# Nearest to 'his': their, the, its, her,
# Nearest to 'united': electorate, agouti, patriots, agave,
# Nearest to 'states': hydrophilic, bolt, tremendously, noa,
# Nearest to 'history': serie, circ, trophies, dasyprocta,
#
# Average loss at step  54000 :  5.1941414
# Nearest to 'from': in, into, agouti, on,
# Nearest to 'with': in, by, or, ursus,
# Nearest to 'five': six, four, eight, three,
# Nearest to 'an': the, completeness, its, demand,
# Nearest to 'would': can, will, should, could,
# Nearest to 'some': many, these, the, this,
# Nearest to 'eight': six, nine, seven, five,
# Nearest to 'world': penalties, girardeau, increments, llama,
# Nearest to 'a': the, ursus, operatorname, circ,
# Nearest to 'it': he, this, there, which,
# Nearest to 'about': sc, agouti, ursus, wct,
# Nearest to 'as': ursus, biathlon, wct, poulsen,
# Nearest to 'his': their, its, her, the,
# Nearest to 'united': electorate, agouti, patriots, dmt,
# Nearest to 'states': hydrophilic, bolt, tremendously, noa,
# Nearest to 'history': serie, circ, dasyprocta, trophies,
#
# Average loss at step  56000 :  5.0439897
# Nearest to 'from': in, into, agouti, and,
# Nearest to 'with': in, and, or, by,
# Nearest to 'five': six, four, eight, three,
# Nearest to 'an': completeness, demand, the, its,
# Nearest to 'would': can, will, should, could,
# Nearest to 'some': many, these, this, any,
# Nearest to 'eight': nine, six, seven, four,
# Nearest to 'world': penalties, girardeau, increments, llama,
# Nearest to 'a': the, operatorname, ursus, aba,
# Nearest to 'it': he, this, there, which,
# Nearest to 'about': sc, agouti, ursus, three,
# Nearest to 'as': ursus, poulsen, biathlon, wct,
# Nearest to 'his': their, its, her, the,
# Nearest to 'united': electorate, agouti, patriots, agave,
# Nearest to 'states': hydrophilic, bolt, tremendously, noa,
# Nearest to 'history': serie, dasyprocta, circ, trophies,
#
# Average loss at step  58000 :  5.036135
# Nearest to 'from': in, into, agouti, on,
# Nearest to 'with': in, by, ursus, or,
# Nearest to 'five': six, four, three, eight,
# Nearest to 'an': completeness, demand, rgb, algorithmic,
# Nearest to 'would': can, will, should, could,
# Nearest to 'some': many, these, the, this,
# Nearest to 'eight': six, nine, seven, four,
# Nearest to 'world': girardeau, penalties, increments, ursus,
# Nearest to 'a': the, ursus, operatorname, circ,
# Nearest to 'it': he, this, there, which,
# Nearest to 'about': sc, agouti, ursus, three,
# Nearest to 'as': ursus, biathlon, poulsen, wct,
# Nearest to 'his': their, its, her, the,
# Nearest to 'united': electorate, agouti, patriots, agave,
# Nearest to 'states': hydrophilic, bolt, tremendously, noa,
# Nearest to 'history': serie, dasyprocta, circ, trophies,
#
# Average loss at step  60000 :  4.948319
# Nearest to 'from': in, into, agouti, on,
# Nearest to 'with': in, ursus, by, or,
# Nearest to 'five': six, four, three, eight,
# Nearest to 'an': completeness, ancien, algorithmic, demand,
# Nearest to 'would': can, will, should, could,
# Nearest to 'some': many, these, this, any,
# Nearest to 'eight': nine, seven, six, five,
# Nearest to 'world': girardeau, penalties, increments, ursus,
# Nearest to 'a': the, ursus, operatorname, any,
# Nearest to 'it': he, this, there, which,
# Nearest to 'about': sc, sasaki, agouti, ursus,
# Nearest to 'as': poulsen, biathlon, ursus, wct,
# Nearest to 'his': their, its, her, the,
# Nearest to 'united': agouti, electorate, agave, patriots,
# Nearest to 'states': hydrophilic, bolt, tremendously, five,
# Nearest to 'history': serie, circ, dasyprocta, trophies,
#
# Average loss at step  62000 :  5.029396
# Nearest to 'from': into, in, agouti, on,
# Nearest to 'with': in, ursus, by, dasyprocta,
# Nearest to 'five': six, four, three, eight,
# Nearest to 'an': completeness, fullerenes, demand, ancien,
# Nearest to 'would': can, will, should, could,
# Nearest to 'some': many, these, all, the,
# Nearest to 'eight': nine, seven, six, four,
# Nearest to 'world': callithrix, girardeau, penalties, increments,
# Nearest to 'a': the, ursus, operatorname, archimedean,
# Nearest to 'it': he, this, there, which,
# Nearest to 'about': sc, sasaki, agouti, ursus,
# Nearest to 'as': poulsen, ursus, biathlon, wct,
# Nearest to 'his': their, its, her, the,
# Nearest to 'united': agouti, electorate, agave, patriots,
# Nearest to 'states': hydrophilic, bolt, tremendously, meningitis,
# Nearest to 'history': serie, microcebus, circ, dasyprocta,
#
# Average loss at step  64000 :  4.8322935
# Nearest to 'from': in, into, agouti, on,
# Nearest to 'with': in, and, ursus, by,
# Nearest to 'five': six, four, three, eight,
# Nearest to 'an': completeness, fullerenes, demand, algorithmic,
# Nearest to 'would': can, will, should, could,
# Nearest to 'some': many, these, all, any,
# Nearest to 'eight': seven, six, nine, four,
# Nearest to 'world': callithrix, girardeau, penalties, increments,
# Nearest to 'a': the, operatorname, ursus, archimedean,
# Nearest to 'it': he, this, there, which,
# Nearest to 'about': sc, sasaki, agouti, ursus,
# Nearest to 'as': poulsen, biathlon, ursus, wct,
# Nearest to 'his': their, her, its, the,
# Nearest to 'united': agouti, electorate, agave, patriots,
# Nearest to 'states': hydrophilic, bolt, tremendously, pelvic,
# Nearest to 'history': serie, microcebus, circ, dasyprocta,
#
# Average loss at step  66000 :  4.5956764
# Nearest to 'from': in, into, agouti, on,
# Nearest to 'with': in, upanija, ursus, by,
# Nearest to 'five': four, six, three, eight,
# Nearest to 'an': completeness, fullerenes, demand, ancien,
# Nearest to 'would': can, will, should, could,
# Nearest to 'some': many, these, all, any,
# Nearest to 'eight': six, nine, seven, five,
# Nearest to 'world': callithrix, girardeau, penalties, increments,
# Nearest to 'a': the, operatorname, ursus, archimedean,
# Nearest to 'it': he, this, there, which,
# Nearest to 'about': sc, agouti, sasaki, ursus,
# Nearest to 'as': poulsen, ursus, biathlon, wct,
# Nearest to 'his': their, its, her, the,
# Nearest to 'united': agouti, electorate, agave, patriots,
# Nearest to 'states': hydrophilic, bolt, tremendously, meningitis,
# Nearest to 'history': serie, microcebus, circ, dasyprocta,
#
# Average loss at step  68000 :  4.986621
# Nearest to 'from': into, agouti, in, on,
# Nearest to 'with': in, upanija, ursus, by,
# Nearest to 'five': six, four, three, eight,
# Nearest to 'an': completeness, demand, the, fullerenes,
# Nearest to 'would': can, will, should, could,
# Nearest to 'some': many, these, all, any,
# Nearest to 'eight': six, seven, nine, five,
# Nearest to 'world': callithrix, girardeau, penalties, hagbard,
# Nearest to 'a': the, thaler, operatorname, ursus,
# Nearest to 'it': he, this, there, which,
# Nearest to 'about': sc, sasaki, agouti, ursus,
# Nearest to 'as': poulsen, ursus, wct, biathlon,
# Nearest to 'his': their, her, its, the,
# Nearest to 'united': electorate, agouti, agave, patriots,
# Nearest to 'states': hydrophilic, bolt, tremendously, pelvic,
# Nearest to 'history': serie, microcebus, thaler, dasyprocta,
#
# Average loss at step  70000 :  4.908303
# Nearest to 'from': into, agouti, in, agave,
# Nearest to 'with': upanija, in, ursus, by,
# Nearest to 'five': four, six, three, eight,
# Nearest to 'an': completeness, demand, fullerenes, the,
# Nearest to 'would': can, will, should, could,
# Nearest to 'some': many, these, any, all,
# Nearest to 'eight': six, nine, seven, five,
# Nearest to 'world': callithrix, girardeau, penalties, increments,
# Nearest to 'a': the, thaler, operatorname, ursus,
# Nearest to 'it': he, this, there, which,
# Nearest to 'about': sc, sasaki, agouti, ursus,
# Nearest to 'as': poulsen, ursus, biathlon, wct,
# Nearest to 'his': their, her, its, the,
# Nearest to 'united': agouti, electorate, agave, patriots,
# Nearest to 'states': hydrophilic, bolt, tremendously, meningitis,
# Nearest to 'history': serie, microcebus, thaler, dasyprocta,
#
# Average loss at step  72000 :  4.757449
# Nearest to 'from': into, in, agouti, agave,
# Nearest to 'with': upanija, in, ursus, by,
# Nearest to 'five': four, six, three, eight,
# Nearest to 'an': fullerenes, completeness, demand, pliny,
# Nearest to 'would': can, will, should, could,
# Nearest to 'some': many, these, all, any,
# Nearest to 'eight': nine, six, seven, five,
# Nearest to 'world': callithrix, girardeau, penalties, solf,
# Nearest to 'a': the, thaler, operatorname, ursus,
# Nearest to 'it': he, there, this, which,
# Nearest to 'about': sc, sasaki, agouti, ursus,
# Nearest to 'as': poulsen, ursus, biathlon, wct,
# Nearest to 'his': their, her, its, the,
# Nearest to 'united': agouti, electorate, agave, patriots,
# Nearest to 'states': hydrophilic, bolt, tremendously, pelvic,
# Nearest to 'history': serie, microcebus, thaler, dasyprocta,
#
# Average loss at step  74000 :  4.809948
# Nearest to 'from': into, in, agouti, agave,
# Nearest to 'with': in, upanija, ursus, and,
# Nearest to 'five': four, six, three, eight,
# Nearest to 'an': completeness, demand, fullerenes, the,
# Nearest to 'would': can, will, should, may,
# Nearest to 'some': many, these, the, all,
# Nearest to 'eight': nine, six, seven, five,
# Nearest to 'world': callithrix, girardeau, penalties, increments,
# Nearest to 'a': the, thaler, operatorname, ursus,
# Nearest to 'it': he, this, there, which,
# Nearest to 'about': sc, sasaki, agouti, ursus,
# Nearest to 'as': poulsen, ursus, biathlon, wct,
# Nearest to 'his': their, her, its, the,
# Nearest to 'united': agouti, electorate, agave, patriots,
# Nearest to 'states': hydrophilic, bolt, tremendously, pelvic,
# Nearest to 'history': serie, microcebus, thaler, dasyprocta,
#
# Average loss at step  76000 :  4.7175045
# Nearest to 'from': into, in, agouti, of,
# Nearest to 'with': in, upanija, ursus, microcebus,
# Nearest to 'five': four, six, three, eight,
# Nearest to 'an': demand, completeness, fullerenes, pliny,
# Nearest to 'would': can, will, should, may,
# Nearest to 'some': many, these, all, any,
# Nearest to 'eight': nine, six, seven, five,
# Nearest to 'world': callithrix, penalties, girardeau, increments,
# Nearest to 'a': the, thaler, operatorname, ursus,
# Nearest to 'it': he, there, this, which,
# Nearest to 'about': sc, sasaki, agouti, ursus,
# Nearest to 'as': poulsen, ursus, biathlon, wct,
# Nearest to 'his': their, her, its, the,
# Nearest to 'united': electorate, agouti, patriots, agave,
# Nearest to 'states': hydrophilic, tremendously, bolt, pelvic,
# Nearest to 'history': serie, microcebus, dasyprocta, thaler,
#
# Average loss at step  78000 :  4.7959547
# Nearest to 'from': into, agouti, in, by,
# Nearest to 'with': in, upanija, by, ursus,
# Nearest to 'five': six, four, three, seven,
# Nearest to 'an': demand, fullerenes, completeness, pliny,
# Nearest to 'would': can, will, should, may,
# Nearest to 'some': many, these, all, any,
# Nearest to 'eight': nine, six, seven, five,
# Nearest to 'world': callithrix, girardeau, penalties, increments,
# Nearest to 'a': the, thaler, operatorname, ursus,
# Nearest to 'it': he, there, this, which,
# Nearest to 'about': sc, agouti, sasaki, ursus,
# Nearest to 'as': poulsen, ursus, biathlon, cebus,
# Nearest to 'his': their, her, its, the,
# Nearest to 'united': electorate, agouti, patriots, agave,
# Nearest to 'states': hydrophilic, tremendously, bolt, pelvic,
# Nearest to 'history': microcebus, serie, dasyprocta, circ,
#
# Average loss at step  80000 :  4.795984
# Nearest to 'from': into, in, agouti, through,
# Nearest to 'with': in, upanija, by, between,
# Nearest to 'five': four, six, seven, three,
# Nearest to 'an': fullerenes, demand, completeness, pliny,
# Nearest to 'would': can, will, should, may,
# Nearest to 'some': many, these, all, any,
# Nearest to 'eight': nine, seven, six, five,
# Nearest to 'world': callithrix, girardeau, penalties, pontificia,
# Nearest to 'a': the, ursus, operatorname, thaler,
# Nearest to 'it': he, there, this, which,
# Nearest to 'about': sc, sasaki, agouti, ursus,
# Nearest to 'as': poulsen, ursus, cebus, biathlon,
# Nearest to 'his': their, her, its, the,
# Nearest to 'united': electorate, agouti, agave, patriots,
# Nearest to 'states': hydrophilic, tremendously, bolt, octagonal,
# Nearest to 'history': serie, microcebus, dasyprocta, circ,
#
# Average loss at step  82000 :  4.760126
# Nearest to 'from': into, in, agouti, for,
# Nearest to 'with': upanija, in, by, microcebus,
# Nearest to 'five': six, four, seven, three,
# Nearest to 'an': fullerenes, demand, completeness, ancien,
# Nearest to 'would': can, will, should, may,
# Nearest to 'some': many, these, all, several,
# Nearest to 'eight': seven, six, nine, five,
# Nearest to 'world': callithrix, penalties, girardeau, pontificia,
# Nearest to 'a': the, thaler, ursus, operatorname,
# Nearest to 'it': he, there, this, which,
# Nearest to 'about': sc, sasaki, agouti, ursus,
# Nearest to 'as': ursus, poulsen, biathlon, archie,
# Nearest to 'his': their, her, its, the,
# Nearest to 'united': electorate, agouti, patriots, agave,
# Nearest to 'states': hydrophilic, bolt, tremendously, octagonal,
# Nearest to 'history': serie, microcebus, dasyprocta, circ,
#
# Average loss at step  84000 :  4.750878
# Nearest to 'from': into, in, agouti, by,
# Nearest to 'with': in, by, upanija, when,
# Nearest to 'five': six, four, seven, eight,
# Nearest to 'an': fullerenes, pliny, demand, completeness,
# Nearest to 'would': can, will, should, may,
# Nearest to 'some': many, these, all, several,
# Nearest to 'eight': seven, six, nine, five,
# Nearest to 'world': callithrix, penalties, girardeau, pontificia,
# Nearest to 'a': the, any, this, ursus,
# Nearest to 'it': he, this, there, which,
# Nearest to 'about': sc, sasaki, agouti, ursus,
# Nearest to 'as': ursus, poulsen, biathlon, wct,
# Nearest to 'his': their, her, its, the,
# Nearest to 'united': electorate, agouti, of, agave,
# Nearest to 'states': hydrophilic, bolt, tremendously, octagonal,
# Nearest to 'history': serie, microcebus, dasyprocta, circ,
#
# Average loss at step  86000 :  4.77019
# Nearest to 'from': in, into, agouti, through,
# Nearest to 'with': in, upanija, between, by,
# Nearest to 'five': six, four, seven, eight,
# Nearest to 'an': fullerenes, demand, completeness, ancien,
# Nearest to 'would': can, will, should, may,
# Nearest to 'some': many, these, all, several,
# Nearest to 'eight': seven, nine, six, five,
# Nearest to 'world': callithrix, girardeau, penalties, pontificia,
# Nearest to 'a': the, any, thaler, operatorname,
# Nearest to 'it': he, this, there, which,
# Nearest to 'about': sc, sasaki, agouti, ursus,
# Nearest to 'as': ursus, biathlon, by, poulsen,
# Nearest to 'his': their, her, its, the,
# Nearest to 'united': electorate, agouti, agave, patriots,
# Nearest to 'states': hydrophilic, bolt, tremendously, octagonal,
# Nearest to 'history': microcebus, serie, dasyprocta, circ,
#
# Average loss at step  88000 :  4.7643175
# Nearest to 'from': into, in, agouti, through,
# Nearest to 'with': in, upanija, between, when,
# Nearest to 'five': four, six, seven, eight,
# Nearest to 'an': fullerenes, completeness, demand, ancien,
# Nearest to 'would': can, will, may, should,
# Nearest to 'some': many, these, several, any,
# Nearest to 'eight': seven, nine, six, five,
# Nearest to 'world': callithrix, girardeau, penalties, pontificia,
# Nearest to 'a': the, thaler, any, ursus,
# Nearest to 'it': he, this, there, which,
# Nearest to 'about': sc, sasaki, agouti, ursus,
# Nearest to 'as': ursus, biathlon, poulsen, archie,
# Nearest to 'his': their, her, its, the,
# Nearest to 'united': electorate, agouti, agave, patriots,
# Nearest to 'states': hydrophilic, bolt, tremendously, octagonal,
# Nearest to 'history': microcebus, dasyprocta, thaler, serie,
#
# Average loss at step  90000 :  4.74696
# Nearest to 'from': into, agouti, in, through,
# Nearest to 'with': in, between, upanija, when,
# Nearest to 'five': four, seven, eight, six,
# Nearest to 'an': fullerenes, ancien, rgb, completeness,
# Nearest to 'would': can, will, may, should,
# Nearest to 'some': many, these, several, all,
# Nearest to 'eight': seven, nine, six, five,
# Nearest to 'world': callithrix, girardeau, penalties, pontificia,
# Nearest to 'a': the, any, thaler, ursus,
# Nearest to 'it': he, this, there, which,
# Nearest to 'about': sc, sasaki, agouti, ursus,
# Nearest to 'as': ursus, poulsen, biathlon, by,
# Nearest to 'his': their, her, its, the,
# Nearest to 'united': electorate, agouti, agave, patriots,
# Nearest to 'states': hydrophilic, bolt, octagonal, tremendously,
# Nearest to 'history': microcebus, serie, dasyprocta, thaler,
#
# Average loss at step  92000 :  4.663962
# Nearest to 'from': into, agouti, in, through,
# Nearest to 'with': in, between, upanija, when,
# Nearest to 'five': seven, eight, four, six,
# Nearest to 'an': the, rgb, fullerenes, its,
# Nearest to 'would': can, will, may, should,
# Nearest to 'some': many, these, several, all,
# Nearest to 'eight': seven, nine, six, five,
# Nearest to 'world': callithrix, girardeau, penalties, pontificia,
# Nearest to 'a': the, peacocks, any, thaler,
# Nearest to 'it': he, this, there, she,
# Nearest to 'about': sc, sasaki, but, agouti,
# Nearest to 'as': ursus, poulsen, biathlon, wct,
# Nearest to 'his': their, her, its, the,
# Nearest to 'united': electorate, agouti, agave, patriots,
# Nearest to 'states': hydrophilic, bolt, octagonal, tremendously,
# Nearest to 'history': serie, microcebus, thaler, dasyprocta,
#
# Average loss at step  94000 :  4.7303796
# Nearest to 'from': into, agouti, in, through,
# Nearest to 'with': in, between, upanija, when,
# Nearest to 'five': seven, eight, four, six,
# Nearest to 'an': fullerenes, rgb, completeness, demand,
# Nearest to 'would': can, will, may, should,
# Nearest to 'some': many, these, several, all,
# Nearest to 'eight': seven, five, six, nine,
# Nearest to 'world': callithrix, girardeau, penalties, pontificia,
# Nearest to 'a': the, any, thaler, operatorname,
# Nearest to 'it': he, this, there, she,
# Nearest to 'about': sc, sasaki, agouti, experiment,
# Nearest to 'as': ursus, poulsen, biathlon, wct,
# Nearest to 'his': their, her, its, the,
# Nearest to 'united': electorate, agouti, agave, patriots,
# Nearest to 'states': hydrophilic, bolt, octagonal, tremendously,
# Nearest to 'history': serie, microcebus, thaler, dasyprocta,
#
# Average loss at step  96000 :  4.677691
# Nearest to 'from': into, through, agouti, in,
# Nearest to 'with': in, between, upanija, when,
# Nearest to 'five': seven, four, six, eight,
# Nearest to 'an': fullerenes, rgb, completeness, demand,
# Nearest to 'would': can, will, may, should,
# Nearest to 'some': many, these, several, the,
# Nearest to 'eight': seven, six, five, nine,
# Nearest to 'world': callithrix, girardeau, penalties, pontificia,
# Nearest to 'a': the, any, thaler, ursus,
# Nearest to 'it': he, this, there, she,
# Nearest to 'about': sc, sasaki, agouti, ursus,
# Nearest to 'as': poulsen, ursus, biathlon, wct,
# Nearest to 'his': their, her, its, my,
# Nearest to 'united': electorate, agouti, agave, patriots,
# Nearest to 'states': hydrophilic, bolt, octagonal, tremendously,
# Nearest to 'history': microcebus, dasyprocta, thaler, serie,
#
# Average loss at step  98000 :  4.605208
# Nearest to 'from': into, agouti, through, in,
# Nearest to 'with': between, in, upanija, when,
# Nearest to 'five': four, six, seven, eight,
# Nearest to 'an': rgb, fullerenes, its, demand,
# Nearest to 'would': can, will, may, should,
# Nearest to 'some': many, these, several, any,
# Nearest to 'eight': seven, six, five, nine,
# Nearest to 'world': callithrix, penalties, girardeau, pontificia,
# Nearest to 'a': the, any, operatorname, ursus,
# Nearest to 'it': he, this, there, she,
# Nearest to 'about': sc, sasaki, agouti, materiel,
# Nearest to 'as': poulsen, ursus, biathlon, when,
# Nearest to 'his': their, her, its, my,
# Nearest to 'united': electorate, agouti, agave, patriots,
# Nearest to 'states': hydrophilic, bolt, octagonal, tremendously,
# Nearest to 'history': microcebus, dasyprocta, thaler, serie,
#
# Average loss at step  100000 :  4.701794
# Nearest to 'from': into, in, through, agouti,
# Nearest to 'with': in, between, upanija, when,
# Nearest to 'five': four, seven, three, six,
# Nearest to 'an': rgb, fullerenes, ancien, demand,
# Nearest to 'would': can, will, may, could,
# Nearest to 'some': many, these, several, all,
# Nearest to 'eight': seven, nine, six, five,
# Nearest to 'world': callithrix, girardeau, penalties, rgya,
# Nearest to 'a': the, any, operatorname, thaler,
# Nearest to 'it': he, this, there, she,
# Nearest to 'about': sc, sasaki, materiel, agouti,
# Nearest to 'as': ursus, poulsen, wct, biathlon,
# Nearest to 'his': their, her, its, the,
# Nearest to 'united': electorate, agouti, agave, patriots,
# Nearest to 'states': hydrophilic, bolt, octagonal, tremendously,
# Nearest to 'history': microcebus, dasyprocta, thaler, serie,

# %% [markdown]
# <center><img src="../images/watiing.jpg" width="700"/></center>

# %% [markdown]
# -----
# Step 6: Visualize the embeddings with t-SNE.
# ----

# %% [markdown]
# In this step, we use the t-SNE algorithm to reduce the dimensionality of the learned word embeddings for visualization.
#
# The top 500 words (based on frequency) are plotted in a 2D space, allowing us to visually inspect the relationships and groupings among words.
#
# This visualization is a powerful tool to understand how well the model has learned semantic relationships.

# %%
tsne = TSNE(perplexity=30, 
            n_components=2, 
            init='pca', 
            max_iter=5000)
plot_only = 500
low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only,:])
labels = [reverse_dictionary[i] for i in range(plot_only)]

n_words_to_visualize = 40

for i, label in enumerate(labels[:n_words_to_visualize]):
        x, y = low_dim_embs[i,:]
        plt.scatter(x, y)
        plt.annotate(label,
                     xy=(x, y),
                     xytext=(5, 2),
                     textcoords='offset points',
                     ha='right',
                     va='bottom')

# %% [markdown]
# ------
#
# # Let's render and plot more samples.

# %%
def plot_with_labels(low_dim_embs, labels, filename='../images/tsne.png'):
    assert low_dim_embs.shape[0] >= len(labels), "More labels than embeddings"
    plt.figure(figsize=(18, 18))  #in inches
    for i, label in enumerate(labels):
        x, y = low_dim_embs[i,:]
        plt.scatter(x, y)
        plt.annotate(label,
                     xy=(x, y),
                     xytext=(5, 2),
                     textcoords='offset points',
                     ha='right',
                     va='bottom')

# %%
tsne = TSNE(perplexity=30, n_components=2, init='pca', max_iter=5000)
plot_only = 500
low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only,:])
labels = [reverse_dictionary[i] for i in range(plot_only)]
plot_with_labels(low_dim_embs, labels)

# %% [markdown]
# # And voila!
#
# Now you have a visual understanding of embeddings.

# %% [markdown]
# Thank you for following this tutorial!
